# %%
from config import DATA_PATH, CHECKPOINT_PATH
from test import make_inference
from utils import plot_random_pred_mask

# %% [markdown]
# The values of Dice loss and IoU metric on test data are quite good

# %%
make_inference(DATA_PATH, CHECKPOINT_PATH, stage='test')
# Out:
# {'test_loss': 0.13051638007164001, 'test_metric': 0.7889586091041565}

# %%
pred, mask = make_inference(DATA_PATH, CHECKPOINT_PATH, stage='predict')

# %% [markdown]
# Let's plot random pairs of the predicted and true masks

# %%
plot_random_pred_mask(pred, mask)

# %%
plot_random_pred_mask(pred, mask)

# %%
plot_random_pred_mask(pred, mask)

# %% [markdown]
# Few masks have been predicted worse

# %%
plot_random_pred_mask(pred, mask)

# %%
plot_random_pred_mask(pred, mask)
